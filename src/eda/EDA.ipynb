# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\DharRawal\\anaconda3\\python.exe'

# %%
# Install a conda package in the current Jupyter kernel
# !conda install --yes --prefix {sys.prefix} -c conda-forge wandb
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DharRawal\anaconda3
#
#   added / updated specs:
#     - wandb
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.11.1              |   py39hcbf5309_1         908 KB  conda-forge
#     docker-pycreds-0.4.0       |             py_0          11 KB  conda-forge
#     gitdb-4.0.10               |     pyhd8ed1ab_0          50 KB  conda-forge
#     gitpython-3.1.30           |     pyhd8ed1ab_0         138 KB  conda-forge
#     pathtools-0.1.2            |             py_1           8 KB  conda-forge
#     promise-2.3                |   py39hcbf5309_7          37 KB  conda-forge
#     ruamel.yaml-0.17.21        |   py39hb82d6ee_1         169 KB  conda-forge
#     ruamel.yaml.clib-0.2.6     |   py39h2bbff1b_1         101 KB
#     sentry-sdk-1.12.1          |     pyhd8ed1ab_0         117 KB  conda-forge
#     setproctitle-1.3.2         |   py39hb82d6ee_0          18 KB  conda-forge
#     shortuuid-1.0.11           |     pyhd8ed1ab_0          13 KB  conda-forge
#     smmap-3.0.5                |     pyh44b312d_0          22 KB  conda-forge
#     wandb-0.13.7               |     pyhd8ed1ab_0         1.3 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   docker-pycreds     conda-forge/noarch::docker-pycreds-0.4.0-py_0 None
#   gitdb              conda-forge/noarch::gitdb-4.0.10-pyhd8ed1ab_0 None
#   gitpython          conda-forge/noarch::gitpython-3.1.30-pyhd8ed1ab_0 None
#   pathtools          conda-forge/noarch::pathtools-0.1.2-py_1 None
#   promise            conda-forge/win-64::promise-2.3-py39hcbf5309_7 None
#   ruamel.yaml        conda-forge/win-64::ruamel.yaml-0.17.21-py39hb82d6ee_1 None
#   ruamel.yaml.clib   pkgs/main/win-64::ruamel.yaml.clib-0.2.6-py39h2bbff1b_1 None
#   sentry-sdk         conda-forge/noarch::sentry-sdk-1.12.1-pyhd8ed1ab_0 None
#   setproctitle       conda-forge/win-64::setproctitle-1.3.2-py39hb82d6ee_0 None
#   shortuuid          conda-forge/noarch::shortuuid-1.0.11-pyhd8ed1ab_0 None
#   smmap              conda-forge/noarch::smmap-3.0.5-pyh44b312d_0 None
#   wandb              conda-forge/noarch::wandb-0.13.7-pyhd8ed1ab_0 None
#
# The following packages will be UPDATED:
#
#   conda                               22.9.0-py39hcbf5309_1 --> 22.11.1-py39hcbf5309_1 None
#
#
#
# Downloading and Extracting Packages
#
# ruamel.yaml.clib-0.2 | 101 KB    |            |   0%
# ruamel.yaml.clib-0.2 | 101 KB    | #5         |  16%
# ruamel.yaml.clib-0.2 | 101 KB    | ########## | 100%
#
# gitpython-3.1.30     | 138 KB    |            |   0%
# gitpython-3.1.30     | 138 KB    | #1         |  12%
# gitpython-3.1.30     | 138 KB    | ########## | 100%
#
# pathtools-0.1.2      | 8 KB      |            |   0%
# pathtools-0.1.2      | 8 KB      | ########## | 100%
#
# smmap-3.0.5          | 22 KB     |            |   0%
# smmap-3.0.5          | 22 KB     | ########## | 100%
#
# wandb-0.13.7         | 1.3 MB    |            |   0%
# wandb-0.13.7         | 1.3 MB    | #4         |  15%
# wandb-0.13.7         | 1.3 MB    | ####8      |  48%
# wandb-0.13.7         | 1.3 MB    | ########4  |  84%
# wandb-0.13.7         | 1.3 MB    | ########## | 100%
#
# docker-pycreds-0.4.0 | 11 KB     |            |   0%
# docker-pycreds-0.4.0 | 11 KB     | ########## | 100%
#
# sentry-sdk-1.12.1    | 117 KB    |            |   0%
# sentry-sdk-1.12.1    | 117 KB    | ########## | 100%
# sentry-sdk-1.12.1    | 117 KB    | ########## | 100%
#
# setproctitle-1.3.2   | 18 KB     |            |   0%
# setproctitle-1.3.2   | 18 KB     | #########  |  90%
# setproctitle-1.3.2   | 18 KB     | ########## | 100%
#
# ruamel.yaml-0.17.21  | 169 KB    |            |   0%
# ruamel.yaml-0.17.21  | 169 KB    | ########## | 100%
# ruamel.yaml-0.17.21  | 169 KB    | ########## | 100%
#
# promise-2.3          | 37 KB     |            |   0%
# promise-2.3          | 37 KB     | ####3      |  44%
# promise-2.3          | 37 KB     | ########## | 100%
#
# gitdb-4.0.10         | 50 KB     |            |   0%
# gitdb-4.0.10         | 50 KB     | ########## | 100%
# gitdb-4.0.10         | 50 KB     | ########## | 100%
#
# shortuuid-1.0.11     | 13 KB     |            |   0%
# shortuuid-1.0.11     | 13 KB     | ########## | 100%
#
# conda-22.11.1        | 908 KB    |            |   0%
# conda-22.11.1        | 908 KB    | ##4        |  25%
# conda-22.11.1        | 908 KB    | #########3 |  93%
# conda-22.11.1        | 908 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
import wandb
import pandas as pd

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ········
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\DharRawal/.netrc
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>C:\Users\DharRawal\Documents\ML Pipeline For NYC Rental Prices\wandb\run-20230107_122219-3o16kfyj</code>
# Syncing run <strong><a href="https://wandb.ai/radiant-logic/nyc_airbnb/runs/3o16kfyj" target="_blank">hopeful-paper-2</a></strong> to <a href="https://wandb.ai/radiant-logic/nyc_airbnb" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# !conda install --yes --prefix {sys.prefix} pandas-profiling
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DharRawal\anaconda3
#
#   added / updated specs:
#     - pandas-profiling
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.11.1              |   py39haa95532_4         892 KB
#     htmlmin-0.1.12             |     pyhd3eb1b0_1          24 KB
#     imagehash-4.2.1            |     pyhd3eb1b0_0         285 KB
#     missingno-0.4.2            |     pyhd3eb1b0_1          15 KB
#     multimethod-1.5            |     pyhd3eb1b0_0          11 KB
#     pandas-profiling-3.4.0     |   py39haa95532_0         292 KB
#     phik-0.12.3                |   py39h59b6b97_0         682 KB
#     pydantic-1.10.2            |   py39h2bbff1b_0         1.5 MB
#     tangled-up-in-unicode-0.2.0|   py39haa95532_0         5.4 MB
#     visions-0.7.5              |   py39haa95532_0         125 KB
#     ------------------------------------------------------------
#                                            Total:         9.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   htmlmin            pkgs/main/noarch::htmlmin-0.1.12-pyhd3eb1b0_1
#   imagehash          pkgs/main/noarch::imagehash-4.2.1-pyhd3eb1b0_0
#   missingno          pkgs/main/noarch::missingno-0.4.2-pyhd3eb1b0_1
#   multimethod        pkgs/main/noarch::multimethod-1.5-pyhd3eb1b0_0
#   pandas-profiling   pkgs/main/win-64::pandas-profiling-3.4.0-py39haa95532_0
#   phik               pkgs/main/win-64::phik-0.12.3-py39h59b6b97_0
#   pydantic           pkgs/main/win-64::pydantic-1.10.2-py39h2bbff1b_0
#   tangled-up-in-uni~ pkgs/main/win-64::tangled-up-in-unicode-0.2.0-py39haa95532_0
#   visions            pkgs/main/win-64::visions-0.7.5-py39haa95532_0
#
# The following packages will be UPDATED:
#
#   conda              conda-forge::conda-22.11.1-py39hcbf53~ --> pkgs/main::conda-22.11.1-py39haa95532_4
#
#
#
# Downloading and Extracting Packages
#
# visions-0.7.5        | 125 KB    |            |   0%
#
# conda-22.11.1        | 892 KB    |            |   0%
#
#
# imagehash-4.2.1      | 285 KB    |            |   0%
#
#
#
# multimethod-1.5      | 11 KB     |            |   0%
#
#
#
#
# pandas-profiling-3.4 | 292 KB    |            |   0%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    |            |   0%
#
#
#
#
#
#
# missingno-0.4.2      | 15 KB     |            |   0%
#
#
#
#
#
#
#
# phik-0.12.3          | 682 KB    |            |   0%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# htmlmin-0.1.12       | 24 KB     |            |   0%
#
# conda-22.11.1        | 892 KB    | 1          |   2%
#
#
#
# multimethod-1.5      | 11 KB     | ########## | 100%
#
#
# imagehash-4.2.1      | 285 KB    | 5          |   6%
#
#
#
# multimethod-1.5      | 11 KB     | ########## | 100%
#
#
# imagehash-4.2.1      | 285 KB    | ######7    |  67%
#
# conda-22.11.1        | 892 KB    | ##3        |  23%
# visions-0.7.5        | 125 KB    | #2         |  13%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | 1          |   1%
#
#
# imagehash-4.2.1      | 285 KB    | ########## | 100%
#
# conda-22.11.1        | 892 KB    | ####1      |  41%
#
#
#
#
#
#
# missingno-0.4.2      | 15 KB     | ########## | 100%
#
# conda-22.11.1        | 892 KB    | #####7     |  57%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | 8          |   8%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    |            |   0%
# visions-0.7.5        | 125 KB    | ########## | 100%
# visions-0.7.5        | 125 KB    | ########## | 100%
#
#
#
#
#
#
# missingno-0.4.2      | 15 KB     | ########## | 100%
#
#
#
#
#
#
#
# phik-0.12.3          | 682 KB    | 2          |   2%
#
# conda-22.11.1        | 892 KB    | #########1 |  91%
#
#
#
#
# pandas-profiling-3.4 | 292 KB    | 5          |   5%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | ##1        |  21%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | 3          |   3%
#
#
#
#
# pandas-profiling-3.4 | 292 KB    | #6         |  16%
#
#
#
#
#
#
#
# phik-0.12.3          | 682 KB    | #6         |  16%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | ##8        |  29%
#
#
#
#
#
#
#
#
#
# htmlmin-0.1.12       | 24 KB     | ######6    |  67%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | 5          |   5%
#
# conda-22.11.1        | 892 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# htmlmin-0.1.12       | 24 KB     | ########## | 100%
#
#
#
#
# pandas-profiling-3.4 | 292 KB    | ########2  |  82%
#
#
#
#
#
#
#
# phik-0.12.3          | 682 KB    | ######8    |  68%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | ####3      |  44%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | #          |  10%
#
#
#
#
#
#
#
# phik-0.12.3          | 682 KB    | ########9  |  89%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | #####2     |  52%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | #2         |  13%
#
#
#
#
# pandas-profiling-3.4 | 292 KB    | ########## | 100%
#
#
#
#
#
#
#
# phik-0.12.3          | 682 KB    | ########## | 100%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | #######    |  70%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | ##2        |  22%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | ########1  |  82%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | ##7        |  27%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | ###2       |  33%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | #########2 |  93%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | ###7       |  38%
#
#
#
#
#
# pydantic-1.10.2      | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | ####5      |  45%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | #####2     |  52%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | #####8     |  59%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | ######6    |  67%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | #######5   |  75%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | ########4  |  85%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
# tangled-up-in-unicod | 5.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import pandas_profiling

profile = pandas_profiling.ProfileReport(df)
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()

# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">hopeful-paper-2</strong>: <a href="https://wandb.ai/radiant-logic/nyc_airbnb/runs/3o16kfyj" target="_blank">https://wandb.ai/radiant-logic/nyc_airbnb/runs/3o16kfyj</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>.\wandb\run-20230107_122219-3o16kfyj\logs</code>
